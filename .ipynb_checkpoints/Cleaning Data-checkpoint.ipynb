# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
df = pd.read_csv('artwork_data.csv', low_memory=False)

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69201 entries, 0 to 69200
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  69201 non-null  int64
#  1   accession_number    69201 non-null  object
#  2   artist              69201 non-null  object
#  3   artistRole          69201 non-null  object
#  4   artistId            69201 non-null  int64
#  5   title               69201 non-null  object
#  6   dateText            69201 non-null  object
#  7   medium              62817 non-null  object
#  8   creditLine          69198 non-null  object
#  9   year                63823 non-null  object
#  10  acquisitionYear     69156 non-null  float64
#  11  dimensions          66768 non-null  object
#  12  width               65860 non-null  object
#  13  height              65860 non-null  object
#  14  depth               2514 non-null   float64
# ...

# %%
df.shape
# Out:
# (69201, 20)

# %%
df.head(20)
# Out:
#       id accession_number          artist artistRole  artistId  \
# 0   1035           A00001   Blake, Robert     artist        38
# 1   1036           A00002   Blake, Robert     artist        38
# 2   1037           A00003   Blake, Robert     artist        38
# 3   1038           A00004   Blake, Robert     artist        38
# 4   1039           A00005  Blake, William     artist        39
# 5   1040           A00006  Blake, William     artist        39
# 6   1041           A00007  Blake, William     artist        39
# 7   1042           A00008  Blake, William     artist        39
# 8   1043           A00009  Blake, William     artist        39
# 9   1044           A00010  Blake, William     artist        39
# 10  1045           A00011  Blake, William     artist        39
# 11  1046           A00012  Blake, William     artist        39
# 12  1047           A00013  Blake, William     artist        39
# 13  1048           A00014  Blake, William     artist        39
# ...

# %%
df.drop('artistRole', axis=1, inplace=True)

# %%
df.head()
# Out:
#      id accession_number          artist  artistId  \
# 0  1035           A00001   Blake, Robert        38
# 1  1036           A00002   Blake, Robert        38
# 2  1037           A00003   Blake, Robert        38
# 3  1038           A00004   Blake, Robert        38
# 4  1039           A00005  Blake, William        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# ...

# %%
df.drop(columns=['units', 'width', 'height'], )
# Out:
#            id accession_number              artist  artistId  \
# 0        1035           A00001       Blake, Robert        38
# 1        1036           A00002       Blake, Robert        38
# 2        1037           A00003       Blake, Robert        38
# 3        1038           A00004       Blake, Robert        38
# 4        1039           A00005      Blake, William        39
# ...       ...              ...                 ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     16646
# 69197  122961           T13866  P-Orridge, Genesis     16646
# 69198  121181           T13867        Hatoum, Mona      2365
# 69199  112306           T13868       Creed, Martin      2760
# 69200  127035           T13869   Brunias, Agostino      3824
#
#                                                    title  \
# 0      A Figure Bowing before a Seated Old Man with h...
# 1      Two Drawings of Frightened Figures, Probably f...
# 2      The Preaching of Warning. Verso: An Old Man En...
# ...

# %%
import re

# %%
df.columns = [re.sub(r'([A-Z])', r'_\1', x).lower() for x in df.columns]

# %%
df.head()
# Out:
#      id accession_number          artist  artist_id  \
# 0  1035           A00001   Blake, Robert         38
# 1  1036           A00002   Blake, Robert         38
# 2  1037           A00003   Blake, Robert         38
# 3  1038           A00004   Blake, Robert         38
# 4  1039           A00005  Blake, William         39
#
#                                                title               date_text  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# ...

# %%
df.rename(columns={"thumbnail_url": "thumbnail"}, inplace=True)

# %%
df.head()
# Out:
#      id accession_number          artist  artist_id  \
# 0  1035           A00001   Blake, Robert         38
# 1  1036           A00002   Blake, Robert         38
# 2  1037           A00003   Blake, Robert         38
# 3  1038           A00004   Blake, Robert         38
# 4  1039           A00005  Blake, William         39
#
#                                                title               date_text  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# ...

# %%
df.filter(items=['id', 'artist'])
# Out:
#            id              artist
# 0        1035       Blake, Robert
# 1        1036       Blake, Robert
# 2        1037       Blake, Robert
# 3        1038       Blake, Robert
# 4        1039      Blake, William
# ...       ...                 ...
# 69196  122960  P-Orridge, Genesis
# 69197  122961  P-Orridge, Genesis
# 69198  121181        Hatoum, Mona
# 69199  112306       Creed, Martin
# 69200  127035   Brunias, Agostino
#
# [69201 rows x 2 columns]

# %%
df.filter(regex="(!?)year")
# Out:
#          year  acquisition_year
# 0         NaN            1922.0
# 1         NaN            1922.0
# 2      1785.0            1922.0
# 3         NaN            1922.0
# 4      1826.0            1919.0
# ...       ...               ...
# 69196    1975            2013.0
# 69197    1976            2013.0
# 69198    1996            2013.0
# 69199    2000            2013.0
# 69200    1764            2013.0
#
# [69201 rows x 2 columns]

# %%
df['id']
# Out:
# 0          1035
# 1          1036
# 2          1037
# 3          1038
# 4          1039
#           ...
# 69196    122960
# 69197    122961
# 69198    121181
# 69199    112306
# 69200    127035
# Name: id, Length: 69201, dtype: int64

# %%
df['id'][1]
# Out:
# 1036

# %%
df[['artist', 'title']]
# Out:
#                    artist                                              title
# 0           Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1           Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2           Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3           Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4          Blake, William  The Circle of the Lustful: Francesca da Rimini...
# ...                   ...                                                ...
# 69196  P-Orridge, Genesis                        Larvae (from Tampax Romana)
# 69197  P-Orridge, Genesis                   Living Womb (from Tampax Romana)
# 69198        Hatoum, Mona                                      Present Tense
# 69199       Creed, Martin          Work No. 227: The lights going on and off
# 69200   Brunias, Agostino                   Dancing Scene in the West Indies
#
# [69201 rows x 2 columns]

# %%
df[['artist', 'title']]['artist']
# Out:
# 0             Blake, Robert
# 1             Blake, Robert
# 2             Blake, Robert
# 3             Blake, Robert
# 4            Blake, William
#                 ...
# 69196    P-Orridge, Genesis
# 69197    P-Orridge, Genesis
# 69198          Hatoum, Mona
# 69199         Creed, Martin
# 69200     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object

# %%
df[['artist', 'title']]['artist'][1]
# Out:
# 'Blake, Robert'

# %%
df[1:2]
# Out:
#      id accession_number         artist  artist_id  \
# 1  1036           A00002  Blake, Robert         38
#
#                                                title       date_text  \
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#               medium                          credit_line year  \
# 1  Graphite on paper  Presented by Mrs John Richmond 1922  NaN
#
#    acquisition_year             dimensions width height  depth units  \
# 1            1922.0  support: 311 x 213 mm   311  213.0    NaN    mm
#
#   inscription thumbnail_copyright  \
# 1         NaN                 NaN
#
#                                            thumbnail  \
# 1  http://www.tate.org.uk/art/images/work/A/A00/A...
#
#                                                  url
# 1  http://www.tate.org.uk/art/artworks/blake-two-...

# %%
df[1:5]
# Out:
#      id accession_number          artist  artist_id  \
# 1  1036           A00002   Blake, Robert         38
# 2  1037           A00003   Blake, Robert         38
# 3  1038           A00004   Blake, Robert         38
# 4  1039           A00005  Blake, William         39
#
#                                                title               date_text  \
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                         medium  \
# 1                            Graphite on paper
# 2  Graphite on paper. Verso: graphite on paper
# 3                            Graphite on paper
# 4                      Line engraving on paper
#
#                                          credit_line    year  \
# ...

# %%
df[1:5]['artist']
# Out:
# 1     Blake, Robert
# 2     Blake, Robert
# 3     Blake, Robert
# 4    Blake, William
# Name: artist, dtype: object

# %%
df[df.acquisition_year > 1800]['acquisition_year']
# Out:
# 0        1922.0
# 1        1922.0
# 2        1922.0
# 3        1922.0
# 4        1919.0
#           ...
# 69196    2013.0
# 69197    2013.0
# 69198    2013.0
# 69199    2013.0
# 69200    2013.0
# Name: acquisition_year, Length: 69156, dtype: float64

# %%
df[df['acquisition_year'] > 1800]
# Out:
#            id accession_number              artist  artist_id  \
# 0        1035           A00001       Blake, Robert         38
# 1        1036           A00002       Blake, Robert         38
# 2        1037           A00003       Blake, Robert         38
# 3        1038           A00004       Blake, Robert         38
# 4        1039           A00005      Blake, William         39
# ...       ...              ...                 ...        ...
# 69196  122960           T13865  P-Orridge, Genesis      16646
# 69197  122961           T13866  P-Orridge, Genesis      16646
# 69198  121181           T13867        Hatoum, Mona       2365
# 69199  112306           T13868       Creed, Martin       2760
# 69200  127035           T13869   Brunias, Agostino       3824
#
#                                                    title  \
# 0      A Figure Bowing before a Seated Old Man with h...
# 1      Two Drawings of Frightened Figures, Probably f...
# ...

# %%
df.loc[0]
# Out:
# id                                                                  1035
# accession_number                                                  A00001
# artist                                                     Blake, Robert
# artist_id                                                             38
# title                  A Figure Bowing before a Seated Old Man with h...
# date_text                                                 date not known
# medium                 Watercolour, ink, chalk and graphite on paper....
# credit_line                          Presented by Mrs John Richmond 1922
# year                                                                 NaN
# acquisition_year                                                  1922.0
# dimensions                                         support: 394 x 419 mm
# width                                                                394
# height                                                             419.0
# ...

# %%
df.loc[0, :]
# Out:
# id                                                                  1035
# accession_number                                                  A00001
# artist                                                     Blake, Robert
# artist_id                                                             38
# title                  A Figure Bowing before a Seated Old Man with h...
# date_text                                                 date not known
# medium                 Watercolour, ink, chalk and graphite on paper....
# credit_line                          Presented by Mrs John Richmond 1922
# year                                                                 NaN
# acquisition_year                                                  1922.0
# dimensions                                         support: 394 x 419 mm
# width                                                                394
# height                                                             419.0
# ...

# %%
df.loc[0:2, :]
# Out:
#      id accession_number         artist  artist_id  \
# 0  1035           A00001  Blake, Robert         38
# 1  1036           A00002  Blake, Robert         38
# 2  1037           A00003  Blake, Robert         38
#
#                                                title       date_text  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
#
#                            credit_line    year  acquisition_year  \
# 0  Presented by Mrs John Richmond 1922     NaN            1922.0
# 1  Presented by Mrs John Richmond 1922     NaN            1922.0
# ...

# %%
df.loc[0:2, 'title']
# Out:
# 0    A Figure Bowing before a Seated Old Man with h...
# 1    Two Drawings of Frightened Figures, Probably f...
# 2    The Preaching of Warning. Verso: An Old Man En...
# Name: title, dtype: object

# %%
df.loc[0:2, ['title', 'artist']]
# Out:
#                                                title         artist
# 0  A Figure Bowing before a Seated Old Man with h...  Blake, Robert
# 1  Two Drawings of Frightened Figures, Probably f...  Blake, Robert
# 2  The Preaching of Warning. Verso: An Old Man En...  Blake, Robert

# %%
df.loc[[1,5], ['title', 'artist']]
# Out:
#                                                title          artist
# 1  Two Drawings of Frightened Figures, Probably f...   Blake, Robert
# 5      Ciampolo the Barrator Tormented by the Devils  Blake, William

# %%
df.loc[[1,5], 'id':'artist_id']
# Out:
#      id accession_number          artist  artist_id
# 1  1036           A00002   Blake, Robert         38
# 5  1040           A00006  Blake, William         39

# %%
df.loc[df.artist == 'Blake, Robert', :]
# Out:
#      id accession_number         artist  artist_id  \
# 0  1035           A00001  Blake, Robert         38
# 1  1036           A00002  Blake, Robert         38
# 2  1037           A00003  Blake, Robert         38
# 3  1038           A00004  Blake, Robert         38
#
#                                                title       date_text  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
#
#                            credit_line    year  acquisition_year  \
# ...

# %%
df.loc[df.artist == 'Blake, Robert', ['title', 'year']]
# Out:
#                                                title    year
# 0  A Figure Bowing before a Seated Old Man with h...     NaN
# 1  Two Drawings of Frightened Figures, Probably f...     NaN
# 2  The Preaching of Warning. Verso: An Old Man En...  1785.0
# 3     Six Drawings of Figures with Outstretched Arms     NaN

# %%
df.iloc[0, :]
# Out:
# id                                                                  1035
# accession_number                                                  A00001
# artist                                                     Blake, Robert
# artist_id                                                             38
# title                  A Figure Bowing before a Seated Old Man with h...
# date_text                                                 date not known
# medium                 Watercolour, ink, chalk and graphite on paper....
# credit_line                          Presented by Mrs John Richmond 1922
# year                                                                 NaN
# acquisition_year                                                  1922.0
# dimensions                                         support: 394 x 419 mm
# width                                                                394
# height                                                             419.0
# ...

# %%
df.iloc[0:3, :]
# Out:
#      id accession_number         artist  artist_id  \
# 0  1035           A00001  Blake, Robert         38
# 1  1036           A00002  Blake, Robert         38
# 2  1037           A00003  Blake, Robert         38
#
#                                                title       date_text  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
#
#                            credit_line    year  acquisition_year  \
# 0  Presented by Mrs John Richmond 1922     NaN            1922.0
# 1  Presented by Mrs John Richmond 1922     NaN            1922.0
# ...

# %%
df.loc[0:3, :]
# Out:
#      id accession_number         artist  artist_id  \
# 0  1035           A00001  Blake, Robert         38
# 1  1036           A00002  Blake, Robert         38
# 2  1037           A00003  Blake, Robert         38
# 3  1038           A00004  Blake, Robert         38
#
#                                                title       date_text  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
#
#                            credit_line    year  acquisition_year  \
# ...

# %%
df.set_index('id', inplace=True)

# %%
df.head()
# Out:
#      accession_number          artist  artist_id  \
# id
# 1035           A00001   Blake, Robert         38
# 1036           A00002   Blake, Robert         38
# 1037           A00003   Blake, Robert         38
# 1038           A00004   Blake, Robert         38
# 1039           A00005  Blake, William         39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# 1039  The Circle of the Lustful: Francesca da Rimini...
#
#                    date_text  \
# id
# 1035          date not known
# 1036          date not known
# 1037                 ?c.1785
# 1038          date not known
# 1039  1826–7, reprinted 1892
#
#                                                  medium  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.iloc[0:3, :]
# Out:
#      accession_number         artist  artist_id  \
# id
# 1035           A00001  Blake, Robert         38
# 1036           A00002  Blake, Robert         38
# 1037           A00003  Blake, Robert         38
#
#                                                   title       date_text  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...  date not known
# 1036  Two Drawings of Frightened Figures, Probably f...  date not known
# 1037  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                                  medium  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....
# 1036                                  Graphite on paper
# 1037        Graphite on paper. Verso: graphite on paper
#
#                               credit_line    year  acquisition_year  \
# id
# 1035  Presented by Mrs John Richmond 1922     NaN            1922.0
# 1036  Presented by Mrs John Richmond 1922     NaN            1922.0
# ...

# %%
df.loc[1035:1037, :]
# Out:
#      accession_number         artist  artist_id  \
# id
# 1035           A00001  Blake, Robert         38
# 1036           A00002  Blake, Robert         38
# 1037           A00003  Blake, Robert         38
#
#                                                   title       date_text  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...  date not known
# 1036  Two Drawings of Frightened Figures, Probably f...  date not known
# 1037  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                                  medium  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....
# 1036                                  Graphite on paper
# 1037        Graphite on paper. Verso: graphite on paper
#
#                               credit_line    year  acquisition_year  \
# id
# 1035  Presented by Mrs John Richmond 1922     NaN            1922.0
# 1036  Presented by Mrs John Richmond 1922     NaN            1922.0
# ...

# %%
df.iloc[0:3, 0:3]
# Out:
#      accession_number         artist  artist_id
# id
# 1035           A00001  Blake, Robert         38
# 1036           A00002  Blake, Robert         38
# 1037           A00003  Blake, Robert         38

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#      id accession_number          artist  artist_id  \
# 0  1035           A00001   Blake, Robert         38
# 1  1036           A00002   Blake, Robert         38
# 2  1037           A00003   Blake, Robert         38
# 3  1038           A00004   Blake, Robert         38
# 4  1039           A00005  Blake, William         39
#
#                                                title               date_text  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# ...

# %%
df.iloc[0:3, 0:3]
# Out:
#      id accession_number         artist
# 0  1035           A00001  Blake, Robert
# 1  1036           A00002  Blake, Robert
# 2  1037           A00003  Blake, Robert

# %%
df.iloc[[5, 8], [0, 2]]
# Out:
#      id          artist
# 5  1040  Blake, William
# 8  1043  Blake, William

# %%
df.medium
# Out:
# 0        Watercolour, ink, chalk and graphite on paper....
# 1                                        Graphite on paper
# 2              Graphite on paper. Verso: graphite on paper
# 3                                        Graphite on paper
# 4                                  Line engraving on paper
#                                ...
# 69196     Perspex, Wood, hairpiece, tampon and human blood
# 69197    Wood, Perspex, plastic, photograph on paper, t...
# 69198                                 Soap and glass beads
# 69199                                     Gallery lighting
# 69200                                  Oil paint on canvas
# Name: medium, Length: 69201, dtype: object

# %%
df.loc[df.title.str.contains('\s$', regex=True)]
# Out:
#           id accession_number                artist artistRole  artistId  \
# 49498   4308           P07466  Hamilton Finlay, Ian     artist      1093
# 50534   2235           P11065         Clarke, Brian     artist       911
# 50535   2236           P11066         Clarke, Brian     artist       911
# 50537   2238           P11068         Clarke, Brian     artist       911
# 53186  21168           P77679     Bourgeois, Louise     artist      2351
# 56283   5826           T00705     Hamilton, Richard     artist      1244
# 67409  88191           T12064          Leach, David     artist      7651
# 67432  88215           T12087        Leach, Bernard     artist      1478
#
#                                                    title dateText  \
# 49498  Port-Distinguishing Letters of Scottish Fishin...     1976
# 50534                                              Boys      1981
# 50535                                         Buildings      1981
# ...

# %%
df.title.str.strip()
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object

# %%
pd.isna(df.loc[:, 'dateText'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: dateText, Length: 69201, dtype: bool

# %%
from numpy import nan

# %%
df.replace({'dateText': {'date not known': nan }}, inplace=True)

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...                     NaN
# 1  Two Drawings of Frightened Figures, Probably f...                     NaN
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms                     NaN
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df = pd.read_csv('artwork_data.csv', low_memory=False)

# %%
df.loc[df.dateText == 'date not known', ['dateText']] = nan

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...                     NaN
# 1  Two Drawings of Frightened Figures, Probably f...                     NaN
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms                     NaN
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.loc[df.year.notnull() & df.year.astype(str).str.contains('[^0-9]'), ['year']] = nan

# %%
df.iloc[67968:67969]
# Out:
#           id accession_number            artist artistRole  artistId  \
# 67968  99332           T12629  Roberts, William     artist      1855
#
#                      title dateText             medium  \
# 67968  Families on a beach  no date  Graphite on paper
#
#                                               creditLine year  \
# 67968  Accepted by HM Government in lieu of inheritan...  NaN
#
#        acquisitionYear             dimensions width height  depth units  \
# 67968           2008.0  support: 127 x 178 mm   127    178    NaN    mm
#
#       inscription               thumbnailCopyright  \
# 67968         NaN  © The estate of William Roberts
#
#                                             thumbnailUrl  \
# 67968  http://www.tate.org.uk/art/images/work/T/T12/T...
#
#                                                      url
# 67968  http://www.tate.org.uk/art/artworks/roberts-fa...

# %%
df.fillna(value={'depth': 0}, inplace=True)

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...                     NaN
# 1  Two Drawings of Frightened Figures, Probably f...                     NaN
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms                     NaN
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df = pd.read_csv('artwork_data.csv', low_memory=False)

# %%
df.shape
# Out:
# (69201, 20)

# %%
df.dropna(thresh=15).shape
# Out:
# (66379, 20)

# %%
df.dropna(subset=['year', 'acquisitionYear']).shape
# Out:
# (63781, 20)

# %%
df.dropna(subset=['year', 'acquisitionYear'], how='all').shape
# Out:
# (69198, 20)

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.dropna(subset=['year', 'acquisitionYear'], inplace=True)

# %%
df.shape
# Out:
# (63781, 20)
